# %%
# !pip install --upgrade matplotlib
# !pip install tensorflow
# !pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the images to a pixel value range of 0 to 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert class labels to one-hot encoded vectors
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate = 1e-3), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, 
                    epochs=30, 
                    batch_size=64, 
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 203s 236ms/step - accuracy: 0.3485 - loss: 2.0287 - val_accuracy: 0.5888 - val_loss: 1.1468
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 174s 223ms/step - accuracy: 0.5727 - loss: 1.1914 - val_accuracy: 0.6519 - val_loss: 0.9901
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 171s 219ms/step - accuracy: 0.6636 - loss: 0.9535 - val_accuracy: 0.6995 - val_loss: 0.8405
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 203s 219ms/step - accuracy: 0.7068 - loss: 0.8383 - val_accuracy: 0.7394 - val_loss: 0.7453
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 172s 219ms/step - accuracy: 0.7375 - loss: 0.7582 - val_accuracy: 0.7615 - val_loss: 0.6927
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 172s 220ms/step - accuracy: 0.7639 - loss: 0.6856 - val_accuracy: 0.7773 - val_loss: 0.6457
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 175s 224ms/step - accuracy: 0.7828 - loss: 0.6344 - val_accuracy: 0.7890 - val_loss: 0.6062
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 200s 221ms/step - accuracy: 0.7924 - loss: 0.6003 - val_accuracy: 0.7855 - val_loss: 0.6374
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 173s 221ms/step - accuracy: 0.8108 - loss: 0.5548 - val_accuracy: 0.7955 - val_loss: 0.6066
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 175s 224ms/step - accuracy: 0.8216 - loss: 0.5230 - val_accuracy: 0.8146 - val_loss: 0.5473
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 173s 221ms/step - accuracy: 0.8329 - loss: 0.4980 - val_accuracy: 0.8114 - val_loss: 0.5434
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 172s 220ms/step - accuracy: 0.8405 - loss: 0.4700 - val_accuracy: 0.8215 - val_loss: 0.5210
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 204s 222ms/step - accuracy: 0.8425 - loss: 0.4588 - val_accuracy: 0.8264 - val_loss: 0.5105
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 202s 222ms/step - accuracy: 0.8532 - loss: 0.4286 - val_accuracy: 0.8256 - val_loss: 0.5362
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 175s 224ms/step - accuracy: 0.8588 - loss: 0.4127 - val_accuracy: 0.8399 - val_loss: 0.4787
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 175s 224ms/step - accuracy: 0.8616 - loss: 0.3990 - val_accuracy: 0.8170 - val_loss: 0.5465
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 201s 222ms/step - accuracy: 0.8718 - loss: 0.3739 - val_accuracy: 0.8428 - val_loss: 0.4859
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 173s 222ms/step - accuracy: 0.8770 - loss: 0.3620 - val_accuracy: 0.8373 - val_loss: 0.5080
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 214s 236ms/step - accuracy: 0.8787 - loss: 0.3544 - val_accuracy: 0.8363 - val_loss: 0.4964
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 205s 240ms/step - accuracy: 0.8787 - loss: 0.3504 - val_accuracy: 0.8232 - val_loss: 0.5660

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')




# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.8477 - loss: 0.5121
# Test accuracy: 0.8482000231742859

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image as keras_image
import matplotlib.pyplot as plt

# Load the CIFAR-10 dataset for label names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Load your trained model
model = tf.keras.models.load_model('model.h5')

# Function to load and preprocess the image
def load_and_preprocess_image(img_path):
    img = keras_image.load_img(img_path, target_size=(32, 32))  # Resize image to 32x32
    img_array = keras_image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Expand dimensions to match model input shape
    img_array = img_array / 255.0  # Normalize the image
    return img_array

img_path = 'airplane.jpg'

# Load and preprocess the image
img_array = load_and_preprocess_image(img_path)

# Make predictions
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions[0])

# Display the result
print(f'Predicted class: {class_names[predicted_class]}')

# Load the image for displaying
img = keras_image.load_img(img_path, target_size=(32, 32))

# Display the image
plt.imshow(img)
plt.title(f'Predicted: {class_names[predicted_class]}')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Predicted class: airplane
