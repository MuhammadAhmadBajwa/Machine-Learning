# %%
# !pip install --upgrade numpy
# !pip install tensorflow
# !pip install matplotlib

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout,BatchNormalization
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    'dataset/training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    'dataset/training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary',
    subset='validation')
# Out:
# Found 6404 images belonging to 2 classes.
# Found 1601 images belonging to 2 classes.

# %%
model=Sequential()

model.add(Conv2D(32,(3,3),activation='relu',input_shape=(64,64,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',
  optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=30)
# Out:
# Epoch 1/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 239ms/step - accuracy: 0.5771 - loss: 0.9639 - val_accuracy: 0.5000 - val_loss: 1.2006
# Epoch 2/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.5938 - loss: 0.7126 - val_accuracy: 0.0000e+00 - val_loss: 4.1156
# Epoch 3/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 241ms/step - accuracy: 0.6615 - loss: 0.6688 - val_accuracy: 0.6119 - val_loss: 0.7502
# Epoch 4/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.6562 - loss: 0.6142 - val_accuracy: 1.0000 - val_loss: 0.6158
# Epoch 5/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 252ms/step - accuracy: 0.6808 - loss: 0.6085 - val_accuracy: 0.6669 - val_loss: 0.6600
# Epoch 6/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.6250 - loss: 0.5743 - val_accuracy: 1.0000 - val_loss: 0.1969
# Epoch 7/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 239ms/step - accuracy: 0.7203 - loss: 0.5483 - val_accuracy: 0.7106 - val_loss: 0.5902
# Epoch 8/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.6875 - loss: 0.5929 - val_accuracy: 0.0000e+00 - val_loss: 0.9905
# Epoch 9/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 241ms/step - accuracy: 0.7444 - loss: 0.5143 - val_accuracy: 0.7362 - val_loss: 0.5255
# Epoch 10/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.7812 - loss: 0.4648 - val_accuracy: 1.0000 - val_loss: 0.0819
# Epoch 11/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 240ms/step - accuracy: 0.7625 - loss: 0.4878 - val_accuracy: 0.7356 - val_loss: 0.5354
# Epoch 12/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 78us/step - accuracy: 0.8125 - loss: 0.5066 - val_accuracy: 1.0000 - val_loss: 0.0188
# Epoch 13/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 239ms/step - accuracy: 0.7504 - loss: 0.5005 - val_accuracy: 0.7456 - val_loss: 0.5363
# Epoch 14/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.7500 - loss: 0.4997 - val_accuracy: 1.0000 - val_loss: 0.4834
# Epoch 15/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 240ms/step - accuracy: 0.7829 - loss: 0.4687 - val_accuracy: 0.7362 - val_loss: 0.5505
# Epoch 16/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 235us/step - accuracy: 0.7188 - loss: 0.5077 - val_accuracy: 1.0000 - val_loss: 7.6527e-05
# Epoch 17/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 239ms/step - accuracy: 0.7913 - loss: 0.4580 - val_accuracy: 0.6656 - val_loss: 0.8038
# Epoch 18/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 78us/step - accuracy: 0.7500 - loss: 0.5349 - val_accuracy: 0.0000e+00 - val_loss: 0.9732
# Epoch 19/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 254ms/step - accuracy: 0.7841 - loss: 0.4554 - val_accuracy: 0.7644 - val_loss: 0.4910
# Epoch 20/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 236us/step - accuracy: 0.8125 - loss: 0.4039 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 21/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 251ms/step - accuracy: 0.7918 - loss: 0.4402 - val_accuracy: 0.7525 - val_loss: 0.5059
# Epoch 22/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.8125 - loss: 0.3678 - val_accuracy: 1.0000 - val_loss: 0.1381
# Epoch 23/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 241ms/step - accuracy: 0.7694 - loss: 0.4611 - val_accuracy: 0.6712 - val_loss: 0.6988
# Epoch 24/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.8438 - loss: 0.4685 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 25/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 240ms/step - accuracy: 0.7853 - loss: 0.4436 - val_accuracy: 0.7706 - val_loss: 0.4735
# Epoch 26/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 79us/step - accuracy: 0.8438 - loss: 0.4530 - val_accuracy: 0.0000e+00 - val_loss: 0.9765
# Epoch 27/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 243ms/step - accuracy: 0.8100 - loss: 0.4169 - val_accuracy: 0.6294 - val_loss: 0.7566
# Epoch 28/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.7812 - loss: 0.4594 - val_accuracy: 0.0000e+00 - val_loss: 0.9440
# Epoch 29/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 242ms/step - accuracy: 0.8108 - loss: 0.4038 - val_accuracy: 0.7119 - val_loss: 0.7130
# Epoch 30/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.6875 - loss: 0.6480 - val_accuracy: 1.0000 - val_loss: 0.5979

# %%
# Evaluate the model
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = train_datagen.flow_from_directory(
    'dataset/test_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
  )
test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)

print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Found 2023 images belonging to 2 classes.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.7159 - loss: 0.6972
# Test accuracy: 71.92%

# %%
model.save('cat_dog_classifier.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Load the trained model
model = load_model('cat_dog_classifier.h5')

# List of image paths
img_paths = ['cat_or_dog.jpg', 'cat_or_dog2.jpg', 'cat_or_dog3.jpg']

# Iterate over each image path
for path in img_paths:
    # Load the image with the specified target size
    img = image.load_img(path, target_size=(64, 64))
    # Convert the image to array and normalize
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Normalize the image

    # Make prediction
    prediction = model.predict(img_array)
    print(prediction)

    # Interpret the result
    label = 'cat'
    if prediction[0] > 0.5:
        label = 'dog'

    # Load the original image for display
    img = image.load_img(path)
    
    # Display the image with the predicted label
    plt.figure()
    plt.title(label)
    plt.imshow(img)
    plt.axis('off')  # Hide the axis

# Show all the plots
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# [[7.489963e-05]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.31502587]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.99469495]]
